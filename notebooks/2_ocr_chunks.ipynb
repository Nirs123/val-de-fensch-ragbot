# %% [markdown]
# # Réalisation de l'OCR et création des chunks
#
# ### Lancement de l'OCR

# %%
import os
from mistralai import Mistral

api_key = os.environ["MISTRAL_API_KEY"]
client = Mistral(api_key=api_key)

# %% [markdown]
# Récupération des liens des fichiers sauvegardés

# %%
files_id = {file.filename[3:7]:file.id for file in client.files.list().data}
files_link = {year:client.files.get_signed_url(file_id=file_id).url for year, file_id in files_id.items()}

# %%
print(files_link)
# Out:
# {'2024': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/9a378ab3b2cd4795b6e66f5a66d1a0b0.pdf?se=2025-08-11T18%3A54%3A54Z&sp=r&sv=2025-07-05&sr=b&sig=Ahno0ncUmhuHIlQwzB0Sp7zx/r11xkfeabXWA/wibUw%3D', '2023': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/1d091d91ed854e5d8a1917bfb3cf9fd3.pdf?se=2025-08-11T18%3A54%3A54Z&sp=r&sv=2025-07-05&sr=b&sig=t0DQDqpfZtJCysTsQN3s2xPHlfiqinQsc8a3gK2aXMU%3D', '2022': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/0cc0a2412a38450c97d0207712d6e55a.pdf?se=2025-08-11T18%3A54%3A54Z&sp=r&sv=2025-07-05&sr=b&sig=uUG33lbJOSU0eKUBqJVn5fHMy6uqgomaqOfpVF9OMW0%3D', '2021': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/b7322fcd313f43eb8303e9908f10daac.pdf?se=2025-08-11T18%3A54%3A54Z&sp=r&sv=2025-07-05&sr=b&sig=wOuzjIUTlY0tcQSo1b33pGJCyPAuq3CU/md3KSSpnGk%3D', '2020': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/5e21c34915aa4c1c83839cc456e35241.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=yYDY2DWWAgC4jD33aDNCTp/Q1lNSU5agACkwSOAhRMY%3D', '2019': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/2e6b5dd09d7742f491176a007e908ef4.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=s41brAJ6RxqvXhuuMskt/5BNaMbMvaGZvnUjfF58zxY%3D', '2018': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/3b8ba2d5d2ed4363af3d6a2d62aa81c5.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=eUr%2BP7nw05IWspxTHgVbfWWVZVWqU8ySidKnTbm2oKs%3D', '2017': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/99bd080cf5f2457fa182e90861391a50.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=nTMGr9D5micDaEg0RdbLdwyD6ZJETiuTKkXxJa%2Bq/bQ%3D', '2016': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/246c75c9c2d646569ef8c7fd75303b4e.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=hmBnU5y8duux3d/TLBP2dJVeSd5TIr8/ku2i97lR0OA%3D', '2015': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/2cd5354b0ee44c1bad4e0eee0867d800.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=Wf72uXdPMTH7bvA%2B0j09VqgqviJK6nsUn%2B8vwZ4oktQ%3D', '2014': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/1ccea6d5f47946dc80b72e85634dee5f.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=tn848SboQwbQKdSGbRcF6lI1S37fo/AsmpVhM3a0IFE%3D', '2013': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/a525d292e1414b618931da8c2a0910eb.pdf?se=2025-08-11T18%3A54%3A55Z&sp=r&sv=2025-07-05&sr=b&sig=4wqmhlOiJotLwz3g5J57asirPwWhZDejA01wJucMwp4%3D', '2012': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/4f4b901b769447ef90dafc26c7a4dea3.pdf?se=2025-08-11T18%3A54%3A56Z&sp=r&sv=2025-07-05&sr=b&sig=g30pZlUWpSrBJYE7JZ60bP1XbSfuC03Cg3uah%2Bz3z2Q%3D', '2011': 'https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/be3813d6-6d95-4101-b138-03210f366e52/7ebab484-cb34-4fe3-8510-a84b67422c23/0334bbe85ac945b2b7d40006011b4504.pdf?se=2025-08-11T18%3A54%3A56Z&sp=r&s ...

# %%
def process_ocr(url):
    return client.ocr.process(
        model="mistral-ocr-latest",
        document={
            "type": "document_url",
            "document_url": url
        },
        include_image_base64=False
    )

# %%
from typing import defaultdict
import json

file_path = "../datasets/ocr_raw.json"

# If OCR was already run once, load it
if os.path.exists(file_path):
    with open(file_path) as json_file:
        files_ocr = json.load(json_file)
        
else:
    files_ocr = defaultdict()

    for year, url in files_link.items():
        print(f"OCR on year {year}")
        ocr_result = process_ocr(url)
        files_ocr[year] = [(i, ocr_result.pages[i].markdown) for i in range(len(ocr_result.pages))]

    with open(file_path, 'w') as json_file:
        json.dump(files_ocr, json_file, indent=4)
# Out:
# OCR on year 2024
# OCR on year 2023
# OCR on year 2022
# OCR on year 2021
# OCR on year 2020
# OCR on year 2019
# OCR on year 2018
# OCR on year 2017
# OCR on year 2016
# OCR on year 2015
# OCR on year 2014
# OCR on year 2013
# OCR on year 2012
# OCR on year 2011
# OCR on year 2010
# OCR on year 2009

# %% [markdown]
# ### Nettoyage de l'OCR
#
# Récupération de toutes les lignes

# %%
ocr_splitted = {year:[(raw_page[0], raw_page[1].split("\n")) for raw_page in ocr_raw] for year, ocr_raw in files_ocr.items()}
print(ocr_splitted)
# Out:
# {'2024': [(0, ['![img-0.jpeg](img-0.jpeg)', '', "# RAPPORT D'ACTIVITÉS ", '', '![img-1.jpeg](img-1.jpeg)']), (1, ['## SOMMAIRE', '', '![img-2.jpeg](img-2.jpeg)', '', '|  DÉVELOPPEMENT ÉCONOMIQUE | 4  |', '| --- | --- |', '|  DÉVELOPPEMENT SOCIAL | 6  |', '|  PETITE ENFANCE | 8  |', '|  SANTÉ | 10  |', '|  CULTURE | 12  |', '|  SPORT | 14  |', '|  ENVIRONNEMENT | 16  |', '|  EAU & ASSAINISSEMENT | 18  |', '|  GESTION DES MILIEUX AQUATIQUES', 'PRÉVENTION DES INONDATIONS | 20  |', '|  AMÉNAGEMENT DU TERRITOIRE | 22  |', '|  BÂTIMENTS, VOIRIES, RÉSEAUX DIVERS | 24  |', '|  FINANCES | 26  |', '|  RESSOURCES HUMAINES | 30  |', '|  COMMANDE PUBLIQUE | 32  |', '|  COMMUNICATION | 34  |', '|  URBANISME | 36  |', "|  SYSTÈMES D'INFORMATION | 38  |", '|  JURIDIQUE | 40  |', '|  LES ÉLUS COMMUNAUTAIRES | 42  |', '|  ORGANIGRAMME DES SERVICES | 44  |', '|  CARTES | 46  |', '', '## LA RICHESSE DU QUOTIDIEN', '', "Rendre compte de son activité est un exercice qui peut apparaître rédhibitoire au premier abord. Aligner des chiffres, énumérer des actions, rappeler ce qui a été fait et que nous connaissons déjà peut plonger dans l'ennui et le désintérêt.", '', "J'y vois pourtant une double nécessité pour notre collectivité :", '', '- Faire connaître son action : sa méconnaissance est autant de possibilité laissée aux faux débats, aux mensonges, qui perturbent nos concitoyens et les détournent encore plus de la chose publique.', "- Reconnaître le travail des agents de la Communauté d'agglomération, depuis les cadres dirigeants jusqu'aux agents, que je félicite pour leur implication et leur action au quotidien en faveur du service public.", '', "2024 s'inscrit dans la continuité des années précédentes. Nous avons adopté en début de mandat un projet de territoire dont l'exécution se poursuit comme vous le verrez dans ce document.", '', 'De grands dossiers stratégiques ont connu en 2024 des avancées décisives :', '', "- L'avenir des friches industrielles de Hayange, Florange et Sertensange-Erzange sur le site de Patural ; nous avons signé en présence d'un ministre le 24 mai un Projet Partenarial d'Aménagement qui assurera que cet espace de plus de 160 ha soit aménagé une fois la dépollution achevée selon l'intérêt public que nous aurons collectivement établi.", "- La fusion avec nos voisins de Portes de France - Thionville dont le processus a été définitivement validé le 1er août par le Préfet qui a signé l'arrêté de modification du périmètre de nos deux collectivités. Le travail de mise en place de la future agglomération a pu débuter dans le respect des équilibres pour les deux territoires.", "- Les Grands Bureaux de Wendel : une réelle fierté pour le Val de Fensch d'avoir trouvé une solution à ce bâtiment, le sauvant de la ruine et lui redonnant vie par la création de plus de 100 logements de standing à Hayange. Le 6 décembre, nous avons procédé à la vente à « Histoire et Patrimoine ».", '', "Vous lirez également dans les pages suivantes la richesse de nos actions au quotidien : sur les chantiers de l'assainissement ou de « Cœur de Villes Cœur de Fensch » ; sur l'accueil de la petite enfance ou la fréquentation (en hausse) de nos équipements culturels et sportifs ; sur nos déchèteries dont nous achevons la modernisation pour un service de qualité aux usagers ; sur nos liens avec les acteurs économiques du territoire depuis le plus petit artisan jusqu'aux industriels de groupes mondiaux ; sur l'activité administrative au service de nos concitoyens, et à la bonne gestion de notre collectivité…", '', "Comme les années précédentes, ce rapport une fois adopté, sera envoyé à chacune des 10 communes et présenté devant nos conseils municipaux respectifs. Au-delà des débats qui traversent notre assemblée, nous pourrons je l'espère nous retrouver pour porter fièrement l'activité de la Communauté d'agglomération du Val de Fensch pour 2024, comme ce fut le cas des années précédentes.", '', '## MICHEL LIEBGOTT', '', "Président de la Communauté d'agglomération ...

# %% [markdown]
# Règles de filtre (dans l'ordre des opérations ):
# - Suppression des expression regex (tout ce qui est contenu entre deux signes $)
# - Suppression du formattage Markdown italique (*) et gras (**)
# - Suppression des lignes vides
# - Suppression des lignes contant des images ou tableau

# %%
import re

ocr_clean = {
    year:[(splitted_page[0] ,[
                re.sub(r'\$.*?\$', '', line).replace("*","").replace("**","") 
                for line in splitted_page[1]
                if not (line == "" or any(char in line for char in ["![", "|"]))
            ])
            for splitted_page in splitted
        ]
    for year, splitted in ocr_splitted.items()
}

# %%
print(ocr_clean)
# Out:
# {'2024': [(0, ["# RAPPORT D'ACTIVITÉS "]), (1, ['## SOMMAIRE', '## LA RICHESSE DU QUOTIDIEN', "Rendre compte de son activité est un exercice qui peut apparaître rédhibitoire au premier abord. Aligner des chiffres, énumérer des actions, rappeler ce qui a été fait et que nous connaissons déjà peut plonger dans l'ennui et le désintérêt.", "J'y vois pourtant une double nécessité pour notre collectivité :", '- Faire connaître son action : sa méconnaissance est autant de possibilité laissée aux faux débats, aux mensonges, qui perturbent nos concitoyens et les détournent encore plus de la chose publique.', "- Reconnaître le travail des agents de la Communauté d'agglomération, depuis les cadres dirigeants jusqu'aux agents, que je félicite pour leur implication et leur action au quotidien en faveur du service public.", "2024 s'inscrit dans la continuité des années précédentes. Nous avons adopté en début de mandat un projet de territoire dont l'exécution se poursuit comme vous le verrez dans ce document.", 'De grands dossiers stratégiques ont connu en 2024 des avancées décisives :', "- L'avenir des friches industrielles de Hayange, Florange et Sertensange-Erzange sur le site de Patural ; nous avons signé en présence d'un ministre le 24 mai un Projet Partenarial d'Aménagement qui assurera que cet espace de plus de 160 ha soit aménagé une fois la dépollution achevée selon l'intérêt public que nous aurons collectivement établi.", "- La fusion avec nos voisins de Portes de France - Thionville dont le processus a été définitivement validé le 1er août par le Préfet qui a signé l'arrêté de modification du périmètre de nos deux collectivités. Le travail de mise en place de la future agglomération a pu débuter dans le respect des équilibres pour les deux territoires.", "- Les Grands Bureaux de Wendel : une réelle fierté pour le Val de Fensch d'avoir trouvé une solution à ce bâtiment, le sauvant de la ruine et lui redonnant vie par la création de plus de 100 logements de standing à Hayange. Le 6 décembre, nous avons procédé à la vente à « Histoire et Patrimoine ».", "Vous lirez également dans les pages suivantes la richesse de nos actions au quotidien : sur les chantiers de l'assainissement ou de « Cœur de Villes Cœur de Fensch » ; sur l'accueil de la petite enfance ou la fréquentation (en hausse) de nos équipements culturels et sportifs ; sur nos déchèteries dont nous achevons la modernisation pour un service de qualité aux usagers ; sur nos liens avec les acteurs économiques du territoire depuis le plus petit artisan jusqu'aux industriels de groupes mondiaux ; sur l'activité administrative au service de nos concitoyens, et à la bonne gestion de notre collectivité…", "Comme les années précédentes, ce rapport une fois adopté, sera envoyé à chacune des 10 communes et présenté devant nos conseils municipaux respectifs. Au-delà des débats qui traversent notre assemblée, nous pourrons je l'espère nous retrouver pour porter fièrement l'activité de la Communauté d'agglomération du Val de Fensch pour 2024, comme ce fut le cas des années précédentes.", '## MICHEL LIEBGOTT', "Président de la Communauté d'agglomération du Val de Fensch Maire de Farnock", 'Membre honoraire du parlement']), (2, ['# ATTRACTIVITÉ & DÉVELOPPEMENT ÉCONOMIQUE', '## FAITS MARQUANTS', "### ZONES D'ACTIVITÉS", '- 18 805 m² de foncier commercialisé sur la ZAC de la Fethère à Fameck et Sainte-Agathe à Fameck/Florange.', "- Signature d'une promesse de vente avec ADM pour la reconversion du site logistique Tenneco à Fameck.", '- Ouverture des entreprises MB Lux Étanchéité et Direct Fenêtres sur le village artisanal de la ZAC la Fethère.', "- Passage à l'éclairage LED des zones d'activités pour un montant de 160 000 €.", '### DIVERS', "- Création d'une newsletter trimestrielle d'informations économiques.", '## INDUSTRIE RÉINDUSTRIALISATION', "- L'ancrement de la démarche Territoire d'Industrie, aux côtés de 9 autres EPCI Nord-Lorrain, visant à concentrer les aides de l'État sur des proje ...

# %% [markdown]
# ### Création des chunks
#
# `ocr_chunks` est un dictionnaire qui contient pour chaque année une liste de chunks
#
# La liste des chunks est une liste de tuples, ayant pour premier élément la catégorie principale du chunk et pour second élément le texte du chunk.

# %%
ocr_chunks = defaultdict(list)

for year, clean_lines in ocr_clean.items():
    hierarchy = ["" for _ in range(3)]
    buffer = []

    tmp_clean_lines = [(line, page[0]) for page in clean_lines for line in page[1]]

    for line, page in tmp_clean_lines:
        if line.startswith("#"):
            if len(buffer) != 0:
                ocr_chunks[year].append((
                    page+1,
                    hierarchy[0] if hierarchy[0] != "" else None,
                    " > ".join([h for h in hierarchy if h]) + "\n" + "\n".join(buffer)
                ))
                buffer = []
            
            nb_hashtag = -1
            for char in line:
                if char == "#":
                    nb_hashtag += 1
                else:
                    break
            
            if nb_hashtag < 3:
                hierarchy[nb_hashtag] = line.replace("#", "").strip()
                for to_clear in range(nb_hashtag+1, 3):
                    hierarchy[to_clear] = ""
        else:
            buffer.append(line)

# %% [markdown]
# Exemple de chunk :

# %%
print("PAGE DU CHUNK: ", ocr_chunks["2024"][0][0])
print("CATEGORIE PRINCIPALE DU CHUNK: ", ocr_chunks["2024"][0][1])
print("CHUNK: \n", ocr_chunks["2024"][0][2])
# Out:
# PAGE DU CHUNK:  2
# CATEGORIE PRINCIPALE DU CHUNK:  RAPPORT D'ACTIVITÉS
# CHUNK:
#  RAPPORT D'ACTIVITÉS > LA RICHESSE DU QUOTIDIEN
# Rendre compte de son activité est un exercice qui peut apparaître rédhibitoire au premier abord. Aligner des chiffres, énumérer des actions, rappeler ce qui a été fait et que nous connaissons déjà peut plonger dans l'ennui et le désintérêt.
# J'y vois pourtant une double nécessité pour notre collectivité :
# - Faire connaître son action : sa méconnaissance est autant de possibilité laissée aux faux débats, aux mensonges, qui perturbent nos concitoyens et les détournent encore plus de la chose publique.
# - Reconnaître le travail des agents de la Communauté d'agglomération, depuis les cadres dirigeants jusqu'aux agents, que je félicite pour leur implication et leur action au quotidien en faveur du service public.
# 2024 s'inscrit dans la continuité des années précédentes. Nous avons adopté en début de mandat un projet de territoire dont l'exécution se poursuit comme vous le verrez dans ce document.
# De grands dossiers stratégiques ont connu en 2024 des avancées décisives :
# - L'avenir des friches industrielles de Hayange, Florange et Sertensange-Erzange sur le site de Patural ; nous avons signé en présence d'un ministre le 24 mai un Projet Partenarial d'Aménagement qui assurera que cet espace de plus de 160 ha soit aménagé une fois la dépollution achevée selon l'intérêt public que nous aurons collectivement établi.
# - La fusion avec nos voisins de Portes de France - Thionville dont le processus a été définitivement validé le 1er août par le Préfet qui a signé l'arrêté de modification du périmètre de nos deux collectivités. Le travail de mise en place de la future agglomération a pu débuter dans le respect des équilibres pour les deux territoires.
# - Les Grands Bureaux de Wendel : une réelle fierté pour le Val de Fensch d'avoir trouvé une solution à ce bâtiment, le sauvant de la ruine et lui redonnant vie par la création de plus de 100 logements de standing à Hayange. Le 6 décembre, nous avons procédé à la vente à « Histoire et Patrimoine ».
# Vous lirez également dans les pages suivantes la richesse de nos actions au quotidien : sur les chantiers de l'assainissement ou de « Cœur de Villes Cœur de Fensch » ; sur l'accueil de la petite enfance ou la fréquentation (en hausse) de nos équipements culturels et sportifs ; sur nos déchèteries dont nous achevons la modernisation pour un service de qualité aux usagers ; sur nos liens avec les acteurs économiques du territoire depuis le plus petit artisan jusqu'aux industriels de groupes mondiaux ; sur l'activité administrative au service de nos concitoyens, et à la bonne gestion de notre collectivité…
# Comme les années précédentes, ce rapport une fois adopté, sera envoyé à chacune des 10 communes et présenté devant nos conseils municipaux respectifs. Au-delà des débats qui traversent notre assemblée, nous pourrons je l'espère nous retrouver pour porter fièrement l'activité de la Communauté d'agglomération du Val de Fensch pour 2024, comme ce fut le cas des années précédentes.

# %% [markdown]
# ### Sauvegarde des chunks

# %%
df_rows = [
    {"year": year, "page": page, "category": category, "chunk": chunk}
    for year, tuple in ocr_chunks.items()
    for page, category, chunk in tuple
]

# %%
print(len(df_rows))
# Out:
# 2128

# %%
import polars as pl

df = pl.DataFrame(df_rows)
print(df)
# Out:
# shape: (2_128, 4)
# ┌──────┬──────┬─────────────────────────────────┬─────────────────────────────────┐
# │ year ┆ page ┆ category                        ┆ chunk                           │
# │ ---  ┆ ---  ┆ ---                             ┆ ---                             │
# │ str  ┆ i64  ┆ str                             ┆ str                             │
# ╞══════╪══════╪═════════════════════════════════╪═════════════════════════════════╡
# │ 2024 ┆ 2    ┆ RAPPORT D'ACTIVITÉS             ┆ RAPPORT D'ACTIVITÉS > LA RICHE… │
# │ 2024 ┆ 3    ┆ RAPPORT D'ACTIVITÉS             ┆ RAPPORT D'ACTIVITÉS > MICHEL L… │
# │ 2024 ┆ 3    ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… │
# │ 2024 ┆ 3    ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… │
# │ 2024 ┆ 3    ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… ┆ ATTRACTIVITÉ & DÉVELOPPEMENT É… │
# │ …    ┆ …    ┆ …                               ┆ …                               │
# │ 2009 ┆ 36   ┆ Système d'information géograph… ┆ Système d'information géograph… │
# │ 2009 ┆ 36   ┆ Communication                   ┆ Communication > Faits marquant… │
# │ 2009 ┆ 36   ┆ Communication                   ┆ Communication > Perspectives 2… │
# │ 2009 ┆ 37   ┆ Communication                   ┆ Communication > Chiffres clés   │
# │      ┆      ┆                                 ┆ …                               │
# │ 2009 ┆ 37   ┆ Communication                   ┆ Communication > Faits marquant… │
# └──────┴──────┴─────────────────────────────────┴─────────────────────────────────┘

# %%
df.write_csv("../datasets/chunks.csv")
